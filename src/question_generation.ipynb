# %% [markdown]
# # Implements rolling questions
#
# - Try Topic Modeling, Glove Word Embeddings for similarity
# - Seq2Seq modelling for question generation.

# %%
answer = """background on 31 december 2019 the world health organization
            china country office was informed of cases of pneumonia of
            unknown aetiology since then there have been over 75 000 cases
            globally of the 2019 novel coronavirus 2000 deaths and over 14
            000 cases recovered outbreaks of novel agents represent
            opportunities for clinical research to inform realtime public
            health action in 2018 we conducted a systematic review to
            identify priority research questions for severe acute
            respiratory syndrome related coronavirus sarscov and middle east
            respiratory syndrome related coronavirus merscov here we review
            information available on covid19 and provide an evidencedbased
            framework for priority clinical research in the current outbreak
            methods three bibliographic databases were searched to identify
            clinical studies published on sarscov and merscov in the
            outbreak setting studies were grouped thematically according to
            clinical research questions addressed in february 2020 available
            information on covid19 was reviewed and compared to the results
            of the sarscov and merscov systematic review from the research
            objectives for sarscov and merscov ten themes in the literature
            were identified clinical characterisation prognosis diagnosis
            clinical management viral pathogenesis epidemiological
            characterisation infection prevention and controltransmission
            susceptibility psychosocial and aetiology for covid19 some
            information on clinical presentation diagnostic testing and
            aetiology is available but many clinical research gaps have yet
            to be filled based on a systematic review of other severe
            coronaviruses we summarise the state of clinical research for
            covid19 highlight the research gaps and provide recommendations
            for the implementation of standardised protocols databased on
            internationally standardised protocols will inform clinical
            practice realtime
            """

# %% [markdown]
# ### POS Tagging

# %%
import spacy

nlp = spacy.load("en_core_web_sm")
doc = nlp(answer)

for token in doc:
    print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
            token.shape_, token.is_alpha, token.is_stop)
# Out:
# background background NOUN NN nsubjpass xxxx True False
# on on ADP IN prep xx True True
# 31 31 NUM CD nummod dd False False
# december december PROPN NNP pobj xxxx True False
# 2019 2019 NUM CD nummod dddd False False
# the the DET DT det xxx True True
# world world PROPN NNP compound xxxx True False
# health health PROPN NNP compound xxxx True False
# organization organization PROPN NNP appos xxxx True False
#
#
#              SPACE _SP
#      False False
# china china PROPN NNP compound xxxx True False
# country country PROPN NNP compound xxxx True False
# office office PROPN NNP nsubjpass xxxx True False
# was be AUX VBD auxpass xxx True True
# informed inform VERB VBN ROOT xxxx True False
# of of ADP IN prep xx True True
# cases case NOUN NNS pobj xxxx True False
# of of ADP IN prep xx True True
# pneumonia pneumonia NOUN NN pobj xxxx True False
# of of ADP IN prep xx True True
#
#
#              SPACE _SP
#      False False
# unknown unknown ADJ JJ amod xxxx True False
# aetiology aetiology NOUN NN pobj xxxx True False
# since since SCONJ IN mark xxxx True True
# then then ADV RB advmod xxxx True True
# there there PRON EX expl xxxx True True
# have have AUX VBP aux xxxx True True
# been be AUX VBN advcl xxxx True True
# over over ADP IN quantmod xxxx True True
# 75 75 NUM CD compound dd False False
# 000 000 NUM CD nummod ddd False False
# cases case NOUN NNS attr xxxx True False
#
#
#              SPACE _SP
#      False False
# globally globally ADV RB advmod xxxx True False
# of of ADP IN prep xx True True
# the the DET DT det xxx True True
# 2019 2019 NUM CD nummod dddd False False
# novel novel NOUN NN nmod xxxx True False
# coronavirus coronavirus PROPN NNP nmod xxxx True False
# 2000 2000 NUM CD nummod dddd False False
# deaths death NOUN NNS pobj xxxx True False
# and and CCONJ CC cc xxx True True
# over over ADP IN advmod xxxx True True
# 14 14 NUM CD nummod dd False False
#
#
#              SPACE _SP
#      False False
# 000 000 NUM CD nummod ddd False False
# cases case NOUN NNS nsubj xxxx True False
# recovered recover VERB VBD ROOT xxxx True False
# outbreaks outbreak NOUN NNS nsubj xxxx True False
# of of ADP IN prep xx True True
# novel novel ADJ JJ amod xxxx True False
# agents agent NOUN NNS pobj xxxx True False
# represent represent VERB VBP ccomp xxxx True False
#
#
#              SPACE _SP
#      False False
# opportunities opportunity NOUN NNS dobj xxxx True False
# for for ADP IN mark xxx True True
# clinical clinical ADJ JJ amod xxxx True False
# research research NOUN NN nsubj xxxx True False
# to to PART TO aux xx True True
# inform inform VERB VB advcl xxxx True False
# realtime realtime ADJ JJ amod xxxx True False
# public public ADJ JJ amod xxxx True False
#
#
#              SPACE _SP
#      False False
# health health NOUN NN compound xxxx True False
# action action NOUN NN dobj xxxx True False
# in in ADP IN prep xx True True
# 2018 2018 NUM CD pobj dddd False False
# we -PRON- PRON PRP nsubj xx True True
# conducted conduct VERB VBD ROOT xxxx True False
# a a DET DT det x True True
# systematic systematic ADJ JJ amod xxxx True False
# review review NOUN NN dobj xxxx True False
# to to ADP IN prep xx True True
#
#
#              SPACE _SP
#      False False
# identify identify VERB VB pobj xxxx True False
# priority priority NOUN NN compound xxxx True False
# research research NOUN NN compound xxxx True False
# questions question NOUN NNS dobj xxxx True False
# for for ADP IN prep xxx True True
# severe severe ADJ JJ amod xxxx True False
# acute acute ADJ JJ compound xxxx True False
#
#
#              SPACE _SP
#      False False
# respiratory respiratory ADJ JJ compound xxxx True False
# syndrome syndrome NOUN NN npadvmod xxxx True False
# related relate VERB VBN amod xxxx True False
# coronavirus coronavirus PROPN NNP compound xxxx True False
# sarscov sarscov PROPN NNP nmod xxxx True False
# and and CCONJ CC cc xxx True True
# middle middle PROPN NNP compound xxxx True False
# east east PROPN NNP conj xxxx True False
#
#
#              SPACE _SP
#      False False
# respiratory respiratory PROPN NNP compound xxxx True False
# syndrome syndrome NOUN NN npadvmod xxxx True False
# related relate VERB VBD amod xxxx True False
# coronavirus coronavirus PROPN NNP compound xxxx True False
# merscov merscov PROPN NNP pobj xxxx True False
# here here ADV RB advmod xxxx True True
# we -PRON- PRON PRP nsubj xx True True
# review review VERB VBP ROOT xxxx True False
#
#
#              SPACE _SP
#      False False
# information information NOUN NN dobj xxxx True False
# available available ADJ JJ amod xxxx True False
# on on ADP IN prep xx True True
# covid19 covid19 NUM CD pobj xxxxdd False False
# and and CCONJ CC cc xxx True True
# provide provide VERB VB conj xxxx True False
# an an DET DT det xx True True
# evidencedbased evidencedbased ADJ JJ amod xxxx True False
#
#
#              SPACE _SP
#      False False
# framework framework NOUN NN dobj xxxx True False
# for for ADP IN prep xxx True True
# priority priority ADJ JJ nmod xxxx True False
# clinical clinical ADJ JJ amod xxxx True False
# research research NOUN NN pobj xxxx True False
# in in ADP IN prep xx True True
# the the DET DT det xxx True True
# current current ADJ JJ amod xxxx True False
# outbreak outbreak NOUN NN pobj xxxx True False
#
#
#              SPACE _SP
#      False False
# methods method NOUN NNS pobj xxxx True False
# three three NUM CD nummod xxxx True True
# bibliographic bibliographic ADJ JJ amod xxxx True False
# databases database NOUN NNS nsubjpass xxxx True False
# were be AUX VBD auxpass xxxx True True
# searched search VERB VBN ROOT xxxx True False
# to to PART TO aux xx True True
# identify identify VERB VB advcl xxxx True False
#
#
#              SPACE _SP
#      False False
# clinical clinical ADJ JJ amod xxxx True False
# studies study NOUN NNS nsubjpass xxxx True False
# published publish VERB VBN acl xxxx True False
# on on ADP IN prep xx True True
# sarscov sarscov PROPN NNP pobj xxxx True False
# and and CCONJ CC cc xxx True True
# merscov merscov PROPN NNP conj xxxx True False
# in in ADP IN prep xx True True
# the the DET DT det xxx True True
#
#
#              SPACE _SP
#      False False
# outbreak outbreak NOUN NN compound xxxx True False
# setting setting NOUN NN compound xxxx True False
# studies study NOUN NNS pobj xxxx True False
# were be AUX VBD auxpass xxxx True True
# grouped group VERB VBN conj xxxx True False
# thematically thematically ADV RB advmod xxxx True False
# according accord VERB VBG prep xxxx True False
# to to ADP IN prep xx True True
#
#
#              SPACE _SP
#      False False
# clinical clinical ADJ JJ amod xxxx True False
# research research NOUN NN compound xxxx True False
# questions question NOUN NNS pobj xxxx True False
# addressed address VERB VBN acl xxxx True False
# in in ADP IN prep xx True True
# february february PROPN NNP npadvmod xxxx True False
# 2020 2020 NUM CD nummod dddd False False
# available available ADJ JJ oprd xxxx True False
#
#
#              SPACE _SP
#      False False
# information information NOUN NN nsubjpass xxxx True False
# on on ADP IN prep xx True True
# covid19 covid19 PROPN NNP pobj xxxxdd False False
# was be AUX VBD auxpass xxx True True
# reviewed review VERB VBN ROOT xxxx True False
# and and CCONJ CC cc xxx True True
# compared compare VERB VBN conj xxxx True False
# to to ADP IN prep xx True True
# the the DET DT det xxx True True
# results result NOUN NNS pobj xxxx True False
#
#
#              SPACE _SP
#      False False
# of of ADP IN prep xx True True
# the the DET DT det xxx True True
# sarscov sarscov PROPN NNP nmod xxxx True False
# and and CCONJ CC cc xxx True True
# merscov merscov PROPN NNP conj xxxx True False
# systematic systematic ADJ JJ amod xxxx True False
# review review NOUN NN pobj xxxx True False
# from from ADP IN prep xxxx True True
# the the DET DT det xxx True True
# research research NOUN NN nmod xxxx True False
#
#
#              SPACE _SP
#      False False
# objectives objective NOUN NNS pobj xxxx True False
# for for ADP IN prep xxx True True
# sarscov sarscov PROPN NNP pobj xxxx True False
# and and CCONJ CC cc xxx True True
# merscov merscov PROPN NNP conj xxxx True False
# ten ten NUM CD nummod xxx True True
# themes theme NOUN NNS nsubjpass xxxx True False
# in in ADP IN prep xx True True
# the the DET DT det xxx True True
# literature literature NOUN NN pobj xxxx True False
#
#
#              SPACE _SP
#      False False
# were be AUX VBD auxpass xxxx True True
# identified identify VERB VBN conj xxxx True False
# clinical clinical ADJ JJ amod xxxx True False
# characterisation characterisation NOUN NN compound xxxx True False
# prognosis prognosis NOUN NN compound xxxx True False
# diagnosis diagnosis PROPN NNP dobj xxxx True False
#
#
#              SPACE _SP
#      False False
# clinical clinical ADJ JJ amod xxxx True False
# management management NOUN NN nmod xxxx True False
# viral viral ADJ JJ amod xxxx True False
# pathogenesis pathogenesis PROPN NNP nmod xxxx True False
# epidemiological epidemiological PROPN NNP amod xxxx True False
#
#
#              SPACE _SP
#      False False
# characterisation characterisation NOUN NN compound xxxx True False
# infection infection NOUN NN compound xxxx True False
# prevention prevention NOUN NN conj xxxx True False
# and and CCONJ CC cc xxx True True
# controltransmission controltransmission PROPN NNP conj xxxx True False
#
#
#              SPACE _SP
#      False False
# susceptibility susceptibility NOUN NN compound xxxx True False
# psychosocial psychosocial NOUN NN conj xxxx True False
# and and CCONJ CC cc xxx True True
# aetiology aetiology NOUN NN conj xxxx True False
# for for ADP IN prep xxx True True
# covid19 covid19 PROPN NNP pobj xxxxdd False False
# some some DET DT det xxxx True True
#
#
#              SPACE _SP
#      False False
# information information NOUN NN nsubj xxxx True False
# on on ADP IN prep xx True True
# clinical clinical ADJ JJ amod xxxx True False
# presentation presentation NOUN NN nmod xxxx True False
# diagnostic diagnostic ADJ JJ amod xxxx True False
# testing testing NOUN NN pobj xxxx True False
# and and CCONJ CC cc xxx True True
#
#
#              SPACE _SP
#      False False
# aetiology aetiology NOUN NN conj xxxx True False
# is be AUX VBZ ROOT xx True True
# available available ADJ JJ acomp xxxx True False
# but but CCONJ CC cc xxx True True
# many many ADJ JJ amod xxxx True True
# clinical clinical ADJ JJ amod xxxx True False
# research research NOUN NN compound xxxx True False
# gaps gap NOUN NNS nsubj xxxx True False
# have have AUX VBP conj xxxx True True
# yet yet ADV RB advmod xxx True True
#
#
#              SPACE _SP
#      False False
# to to PART TO aux xx True True
# be be AUX VB auxpass xx True True
# filled fill VERB VBN xcomp xxxx True False
# based base VERB VBN prep xxxx True False
# on on ADP IN prep xx True True
# a a DET DT det x True True
# systematic systematic ADJ JJ amod xxxx True False
# review review NOUN NN pobj xxxx True False
# of of ADP IN prep xx True True
# other other ADJ JJ amod xxxx True True
# severe severe ADJ JJ amod xxxx True False
#
#
#              SPACE _SP
#      False False
# coronaviruses coronaviruse NOUN NNS pobj xxxx True False
# we -PRON- PRON PRP nsubj xx True True
# summarise summarise VERB VBP ROOT xxxx True False
# the the DET DT det xxx True True
# state state NOUN NN dobj xxxx True False
# of of ADP IN prep xx True True
# clinical clinical ADJ JJ amod xxxx True False
# research research NOUN NN pobj xxxx True False
# for for ADP IN prep xxx True True
#
#
#              SPACE _SP
#      False False
# covid19 covid19 PROPN NNP nummod xxxxdd False False
# highlight highlight VERB VBP pobj xxxx True False
# the the DET DT det xxx True True
# research research NOUN NN compound xxxx True False
# gaps gap NOUN NNS dobj xxxx True False
# and and CCONJ CC cc xxx True True
# provide provide VERB VB conj xxxx True False
# recommendations recommendation NOUN NNS dobj xxxx True False
#
#
#              SPACE _SP
#      False False
# for for ADP IN prep xxx True True
# the the DET DT det xxx True True
# implementation implementation NOUN NN pobj xxxx True False
# of of ADP IN prep xx True True
# standardised standardised ADJ JJ amod xxxx True False
# protocols protocol NOUN NNS pobj xxxx True False
# databased database VERB VBD acl xxxx True False
# on on ADP IN prep xx True True
#
#
#              SPACE _SP
#      False False
# internationally internationally ADV RB advmod xxxx True False
# standardised standardise VERB VBN amod xxxx True False
# protocols protocol NOUN NNS nsubj xxxx True False
# will will VERB MD aux xxxx True True
# inform inform VERB VB conj xxxx True False
# clinical clinical ADJ JJ amod xxxx True False
#
#
#              SPACE _SP
#      False False
# practice practice NOUN NN compound xxxx True False
# realtime realtime NOUN NN dobj xxxx True False
#
#
#              SPACE _SP
#      False False

# %% [markdown]
# ### Extract Named Entities

# %%
import spacy

bag_of_words = []
nlp = spacy.load("en_core_web_sm")
doc = nlp(answer)
for ent in doc.ents:
    bag_of_words.append((ent.text))
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# 31 december 2019 14 30 DATE
# the world health organization
#             china country office 31 93 ORG
# 2019 235 239 DATE
# 2000 258 262 CARDINAL
# 2018 453 457 DATE
# middle east 625 636 LOC
# coronavirus merscov 678 697 PERSON
# three 885 890 CARDINAL
# february 2020 1139 1152 DATE
# ten 1361 1364 CARDINAL

# %% [markdown]
# ### TF-IDF
#
# Find words that don't appear frequently.

# %%
# https://www.machinelearningplus.com/nlp/gensim-tutorial/#8howtocreatethetfidfmatrixcorpusingensim

from gensim import models
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
import numpy as np

documents = [answer]

# Create the Dictionary and Corpus
mydict = corpora.Dictionary([simple_preprocess(line) for line in documents])
corpus = [mydict.doc2bow(simple_preprocess(line)) for line in documents]

# Show the Word Weights in Corpus
for doc in corpus:
    print([[mydict[id], freq] for id, freq in doc])

# Create the TF-IDF model
tfidf = models.TfidfModel(corpus, smartirs='ntc')

# Show the TF-IDF weights
for doc in tfidf[corpus]:
    print([[mydict[id], np.around(freq, decimals=2)] for id, freq in doc])
# Out:
# [['according', 1], ['action', 1], ['acute', 1], ['addressed', 1], ['aetiology', 3], ['agents', 1], ['an', 1], ['and', 11], ['available', 3], ['background', 1], ['based', 1], ['be', 1], ['been', 1], ['bibliographic', 1], ['but', 1], ['cases', 3], ['china', 1], ['clinical', 10], ['compared', 1], ['conducted', 1], ['coronavirus', 3], ['coronaviruses', 1], ['country', 1], ['covid', 4], ['current', 1], ['databased', 1], ['databases', 1], ['deaths', 1], ['december', 1], ['diagnosis', 1], ['diagnostic', 1], ['east', 1], ['epidemiological', 1], ['evidencedbased', 1], ['february', 1], ['filled', 1], ['for', 7], ['framework', 1], ['from', 1], ['gaps', 2], ['globally', 1], ['grouped', 1], ['have', 2], ['health', 2], ['here', 1], ['highlight', 1], ['identified', 1], ['identify', 2], ['implementation', 1], ['in', 5], ['infection', 1], ['inform', 2], ['information', 3], ['informed', 1], ['internationally', 1], ['is', 1], ['literature', 1], ['management', 1], ['many', 1], ['merscov', 4], ['methods', 1], ['middle', 1], ['novel', 2], ['objectives', 1], ['of', 9], ['office', 1], ['on', 7], ['opportunities', 1], ['organization', 1], ['other', 1], ['outbreak', 2], ['outbreaks', 1], ['over', 2], ['pathogenesis', 1], ['pneumonia', 1], ['practice', 1], ['presentation', 1], ['prevention', 1], ['priority', 2], ['prognosis', 1], ['protocols', 2], ['provide', 2], ['psychosocial', 1], ['public', 1], ['published', 1], ['questions', 2], ['realtime', 2], ['recommendations', 1], ['recovered', 1], ['related', 2], ['represent', 1], ['research', 8], ['respiratory', 2], ['results', 1], ['review', 4], ['reviewed', 1], ['sarscov', 4], ['searched', 1], ['setting', 1], ['severe', 2], ['since', 1], ['some', 1], ['standardised', 2], ['state', 1], ['studies', 2], ['summarise', 1], ['susceptibility', 1], ['syndrome', 2], ['systematic', 3], ['ten', 1], ['testing', 1], ['the', 11], ['thematically', 1], ['themes', 1], ['then', 1], ['there', 1], ['three', 1], ['to', 6], ['unknown', 1], ['viral', 1], ['was', 2], ['we', 3], ['were', 3], ['will', 1], ['world', 1], ['yet', 1]]
# [['according', 0.03], ['action', 0.03], ['acute', 0.03], ['addressed', 0.03], ['aetiology', 0.1], ['agents', 0.03], ['an', 0.03], ['and', 0.36], ['available', 0.1], ['background', 0.03], ['based', 0.03], ['be', 0.03], ['been', 0.03], ['bibliographic', 0.03], ['but', 0.03], ['cases', 0.1], ['china', 0.03], ['clinical', 0.32], ['compared', 0.03], ['conducted', 0.03], ['coronavirus', 0.1], ['coronaviruses', 0.03], ['country', 0.03], ['covid', 0.13], ['current', 0.03], ['databased', 0.03], ['databases', 0.03], ['deaths', 0.03], ['december', 0.03], ['diagnosis', 0.03], ['diagnostic', 0.03], ['east', 0.03], ['epidemiological', 0.03], ['evidencedbased', 0.03], ['february', 0.03], ['filled', 0.03], ['for', 0.23], ['framework', 0.03], ['from', 0.03], ['gaps', 0.06], ['globally', 0.03], ['grouped', 0.03], ['have', 0.06], ['health', 0.06], ['here', 0.03], ['highlight', 0.03], ['identified', 0.03], ['identify', 0.06], ['implementation', 0.03], ['in', 0.16], ['infection', 0.03], ['inform', 0.06], ['information', 0.1], ['informed', 0.03], ['internationally', 0.03], ['is', 0.03], ['literature', 0.03], ['management', 0.03], ['many', 0.03], ['merscov', 0.13], ['methods', 0.03], ['middle', 0.03], ['novel', 0.06], ['objectives', 0.03], ['of', 0.29], ['office', 0.03], ['on', 0.23], ['opportunities', 0.03], ['organization', 0.03], ['other', 0.03], ['outbreak', 0.06], ['outbreaks', 0.03], ['over', 0.06], ['pathogenesis', 0.03], ['pneumonia', 0.03], ['practice', 0.03], ['presentation', 0.03], ['prevention', 0.03], ['priority', 0.06], ['prognosis', 0.03], ['protocols', 0.06], ['provide', 0.06], ['psychosocial', 0.03], ['public', 0.03], ['published', 0.03], ['questions', 0.06], ['realtime', 0.06], ['recommendations', 0.03], ['recovered', 0.03], ['related', 0.06], ['represent', 0.03], ['research', 0.26], ['respiratory', 0.06], ['results', 0.03], ['review', 0.13], ['reviewed', 0.03], ['sarscov', 0.13], ['searched', 0.03], ['setting', 0.03], ['severe', 0.06], ['since', 0.03], ['some', 0.03], ['standardised', 0.06], ['state', 0.03], ['studies', 0.06], ['summarise', 0.03], ['susceptibility', 0.03], ['syndrome', 0.06], ['systematic', 0.1], ['ten', 0.03], ['testing', 0.03], ['the', 0.36], ['thematically', 0.03], ['themes', 0.03], ['then', 0.03], ['there', 0.03], ['three', 0.03], ['to', 0.19], ['unknown', 0.03], ['viral', 0.03], ['was', 0.06], ['we', 0.1], ['were', 0.1], ['will', 0.03], ['world', 0.03], ['yet', 0.03]]

# %% [markdown]
# ### Sentence Similarity using Word Embeddings
#
# Good medium article: https://medium.com/@adriensieg/text-similarities-da019229c894
#
# Remove Stop Words
#
# LDA: https://www.kaggle.com/ktattan/lda-and-document-similarity
#
# Get BERT Embeddings for words: https://towardsdatascience.com/bow-to-bert-2695cdb19787
